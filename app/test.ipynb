# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
from modules.data.poloniex.poloniex_api import Poloniex as pl

coin_price_url = "https://poloniex.com/public?command=returnTicker"

# %% [markdown]
# ### Data Reading

# %%
pl(coin_price_url).coin_list
# Out:
# ['BTC_BTS',
#  'BTC_DASH',
#  'BTC_DOGE',
#  'BTC_LTC',
#  'BTC_NXT',
#  'BTC_STR',
#  'BTC_XEM',
#  'BTC_XMR',
#  'BTC_XRP',
#  'USDT_BTC',
#  'USDT_DASH',
#  'USDT_LTC',
#  'USDT_STR',
#  'USDT_XMR',
#  'USDT_XRP',
#  'BTC_ETH',
#  'USDT_ETH',
#  'BTC_SC',
#  'BTC_DCR',
#  'BTC_LSK',
#  'BTC_STEEM',
#  'BTC_ETC',
#  'ETH_ETC',
#  'USDT_ETC',
#  'BTC_ARDR',
#  'BTC_ZEC',
#  'ETH_ZEC',
#  'USDT_ZEC',
#  'BTC_ZRX',
#  'ETH_ZRX',
#  'BTC_CVC',
#  'BTC_OMG',
#  'BTC_GAS',
#  'BTC_STORJ',
#  'BTC_EOS',
#  'ETH_EOS',
#  'USDT_EOS',
#  'BTC_SNT',
#  'BTC_KNC',
#  'BTC_BAT',
#  'USDT_BAT',
#  'BTC_LOOM',
#  'USDT_DOGE',
#  'USDT_LSK',
#  'USDT_SC',
#  'USDT_ZRX',
#  'BTC_QTUM',
#  'USDT_QTUM',
#  'USDC_BTC',
#  'USDC_ETH',
#  'USDC_USDT',
#  'BTC_MANA',
#  'USDT_MANA',
#  'BTC_BNT',
#  'BTC_BCHSV',
#  'USDC_BCHSV',
#  'USDC_XRP',
#  'USDC_XMR',
#  'USDC_STR',
#  'USDC_DOGE',
#  'USDC_LTC',
#  'USDC_ZEC',
#  'BTC_FOAM',
#  'BTC_NMR',
#  'BTC_POLY',
#  'BTC_LPT',
#  'BTC_ATOM',
#  'USDC_ATOM',
#  'USDT_ATOM',
#  'USDC_DASH',
#  'USDC_EOS',
#  'USDC_ETC',
#  'USDT_BCHSV',
#  'BTC_TRX',
#  'USDC_TRX',
#  'USDT_TRX',
#  'TRX_ETH',
#  'TRX_XRP',
#  'USDT_BTT',
#  'TRX_BTT',
#  'USDT_WIN',
#  'TRX_WIN',
#  'TRX_STEEM',
#  'BTC_LINK',
#  'TRX_LINK',
#  'BTC_XTZ',
#  'USDT_XTZ',
#  'TRX_XTZ',
#  'USDT_BEAR',
#  'USDT_BULL',
#  'USDT_TRXBEAR',
#  'USDT_TRXBULL',
#  'PAX_BTC',
#  'PAX_ETH',
#  'USDT_PAX',
#  'USDT_USDJ',
#  'USDJ_BTC',
#  'USDJ_TRX',
#  'BTC_SNX',
#  'USDT_SNX',
#  'TRX_SNX',
#  'USDT_BSVBEAR',
#  'USDT_BSVBULL',
#  'BTC_MATIC',
#  'USDT_MATIC',
#  'TRX_MATIC',
#  'USDT_BCHBEAR',
#  'USDT_BCHBULL',
#  'USDT_ETHBEAR',
#  'USDT_ETHBULL',
#  'BTC_MKR',
#  'USDT_MKR',
#  'USDT_BVOL',
#  'USDT_IBVOL',
#  'DAI_BTC',
#  'DAI_ETH',
#  'USDT_DAI',
#  'BTC_NEO',
#  'USDT_NEO',
#  'TRX_NEO',
#  'BTC_SWFTC',
#  'USDT_SWFTC',
#  'TRX_SWFTC',
#  'USDT_JST',
#  'TRX_JST',
#  'USDT_BCN',
#  'USDT_STEEM',
#  'USDT_LINK',
#  'USDJ_BTT',
#  'BTC_AVA',
#  'USDT_AVA',
#  'TRX_AVA',
#  'USDT_XRPBULL',
#  'USDT_XRPBEAR',
#  'USDT_EOSBULL',
#  'USDT_EOSBEAR',
#  'USDT_LINKBULL',
#  'USDT_LINKBEAR',
#  'BTC_CHR',
#  'USDT_CHR',
#  'TRX_CHR',
#  'BNB_BTC',
#  'USDT_BNB',
#  'USDT_BUSD',
#  'TRX_BNB',
#  'BUSD_BNB',
#  'BUSD_BTC',
#  'BTC_MDT',
#  'USDT_MDT',
#  'TRX_MDT',
#  'USDT_BCHC',
#  'USDT_COMP',
#  'ETH_COMP',
#  'USDT_CUSDT',
#  'BTC_REN',
#  'USDT_REN',
#  'BTC_LRC',
#  'USDT_LRC',
#  'USDT_BAL',
#  'BTC_WRX',
#  'USDT_WRX',
#  'TRX_WRX',
#  'USDT_STAKE',
#  'BTC_SXP',
#  'USDT_SXP',
#  'TRX_SXP',
#  'USDT_MTA',
#  'USDT_YFI',
#  'BTC_STPT',
#  'USDT_STPT',
#  'USDT_DEC',
#  'USDT_UMA',
#  'USDT_KTON',
#  'USDT_RING',
#  'BTC_SWAP',
#  'USDT_SWAP',
#  'USDT_TEND',
#  'BTC_EXE',
#  'USDT_EXE',
#  'USDT_TRADE',
#  'USDT_GEEQ',
#  'USDT_BAND',
#  'USDT_DOS',
#  'USDT_DIA',
#  'USDT_ZAP',
#  'USDT_PERX',
#  'USDT_TRB',
#  'USDT_MCB',
#  'USDT_CRV',
#  'USDT_OM',
#  'USDT_OCEAN',
#  'USDT_BLY',
#  'BTC_SWINGBY',
#  'USDT_SWINGBY',
#  'TRX_SWINGBY',
#  'USDT_PRQ',
#  'USDT_DOT',
#  'USDT_RSR',
#  'USDT_WNXM',
#  'USDT_FCT2',
#  'BTC_FCT2',
#  'USDT_SUSHI',
#  'USDT_YFII',
#  'USDT_YFL',
#  'USDT_TAI',
#  'USDT_PEARL',
#  'USDT_JFI',
#  'USDT_CORN',
#  'USDT_SWRV',
#  'USDT_FSW',
#  'USDT_FUND',
#  'TRX_FUND',
#  'BTC_FUND',
#  'USDT_SUNOLD',
#  'USDT_HGET',
#  'BTC_HGET',
#  'USDT_AKRO',
#  'BTC_AKRO',
#  'USDT_ADEL',
#  'USDT_UNI',
#  'USDT_DHT',
#  'USDT_MEME',
#  'USDT_CVP',
#  'USDT_GHST',
#  'BTC_REPV2',
#  'USDT_REPV2',
#  'USDT_RARI',
#  'USDT_DICE',
#  'TRX_DICE',
#  'BTC_AMP',
#  'USDT_AMP',
#  'TRX_AMP',
#  'BTC_SAND',
#  'USDT_SAND',
#  'USDT_RFUEL',
#  'USDT_VALUE',
#  'USDT_POLS',
#  'BTC_AAVE',
#  'USDT_AAVE',
#  'BTC_BID',
#  'USDT_BID',
#  'BTC_CVT',
#  'USDT_CVT',
#  'BTC_INJ',
#  'USDT_INJ',
#  'BTC_BCH',
#  'USDT_BCH',
#  'USDC_BCH',
#  'BTC_SENSO',
#  'USDT_SENSO',
#  'USDT_KP3R',
#  'USDT_MPH',
#  'BTC_GLM',
#  'USDT_GLM',
#  'USDT_HEGIC',
#  'USDT_ZLOT',
#  'BTC_WBTC',
#  'USDT_WBTC',
#  'USDT_NU',
#  'BTC_FRONT',
#  'USDT_FRONT',
#  'USDT_API3',
#  'USDT_BADGER',
#  'BTC_FARM',
#  'USDT_FARM',
#  'BTC_DOT',
#  'USDT_GRT',
#  'TRX_SUNOLD',
#  'USDT_XFLR',
#  'USDT_ESD',
#  'USDT_ONEINCH',
#  'USDT_REEF',
#  'USDT_BAC',
#  'USDT_LON',
#  'USDT_ROOK',
#  'USDT_TRU',
#  'USDT_CUDOS',
#  'USDT_BOND',
#  'USDT_PBTC35A',
#  'USDT_COMBO',
#  'USDT_TUSD',
#  'USDC_TUSD',
#  'USDT_ADABEAR',
#  'USDT_ADABULL',
#  'USDT_LTCBEAR',
#  'USDT_LTCBULL',
#  'USDT_XLMBEAR',
#  'USDT_XLMBULL',
#  'USDT_WETH',
#  'BTC_TRU',
#  'USDT_FTT',
#  'USDT_SRM',
#  'USDT_LPT',
#  'TUSD_BTC',
#  'TUSD_ETH',
#  'USDT_ALPHA',
#  'USDT_TORN',
#  'USDT_ZKS',
#  'USDT_RNDR',
#  'USDT_VSP',
#  'TRX_VSP',
#  'USDT_BDP',
#  'USDT_ADD',
#  'USDT_KCS',
#  'USDT_BTCST',
#  'USDT_SFI',
#  'BTC_FIL',
#  'USDT_FIL',
#  'BTC_XYM',
#  'USDT_XYM',
#  'USDT_LIVE',
#  'USDT_SHIB',
#  'USDT_AKITA',
#  'USDT_B20',
#  'USDT_KLV',
#  'BTC_KLV',
#  'TRX_KLV',
#  'USDT_LQTY',
#  'USDT_LUSD',
#  'USDT_WHALE',
#  'USDT_NFTX',
#  'USDT_MIR',
#  'USDT_UST',
#  'USDT_DEGO',
#  'USDT_FORTH',
#  'USDT_ELON',
#  'USDT_MIST',
#  'USDT_XOR',
#  'USDT_QUICK',
#  'USDT_MVL',
#  'USDT_NFT',
#  'TRX_NFT',
#  'USDT_HT',
#  'USDT_CTSI',
#  'USDT_RLC',
#  'USDT_ERSDL',
#  'USDT_LEASH',
#  'TRX_KISHU',
#  'USDT_GTC',
#  'USDT_OKB',
#  'USDT_POL',
#  'USDT_SUN',
#  'TRX_SUN',
#  'USDT_XEC',
#  'USDT_CAKE',
#  'USDT_XVS',
#  'USDT_EPS',
#  'USDT_BURGER',
#  'USDT_AUTO',
#  'USDT_NRV',
#  'USDT_AXS',
#  'USDT_YFX',
#  'BTC_YFX',
#  'USDT_ALPACA',
#  'TRX_BABYDOGE',
#  'USDT_C98',
#  'USDT_PERP',
#  'TUSD_TRU',
#  'USDT_ACH1',
#  'USDT_CLV',
#  'USDT_YGG',
#  'USDT_ALICE',
#  'USDT_RD',
#  'USDT_AUDIO',
#  'USDT_BIT',
#  'USDC_BNB',
#  'USDC_LINK',
#  'USDT_MBOX',
#  'USDT_BP',
#  'USDT_OSK',
#  'TRX_OSK',
#  'USDT_LUMI',
#  'TRX_LUMI',
#  'USDT_DFA',
#  'USDT_PUNK',
#  'USDT_GLYPH',
#  'USDT_MASK',
#  'USDT_COOL',
#  'USDT_MATTER',
#  'TRX_MATTER',
#  'USDT_AGLD',
#  'USDC_MATIC',
#  'USDC_MANA',
#  'USDC_XEM',
#  'USDC_BTT',
#  'USDC_SRM',
#  'USDT_XEM',
#  'BTC_SRM',
#  'USDT_DYDX',
#  'USDT_XCAD',
#  'USDT_GALA',
#  'USDT_LDO',
#  'USDT_UMB',
#  'USDT_BIFI',
#  'USDT_IDIA',
#  'USDT_BTRST',
#  'USDT_FLOKI',
#  'USDT_TOKE',
#  'USDT_WNCG',
#  'USDT_MLN',
#  'USDT_WOO',
#  'USDT_LATTE',
#  'USDT_ENJ',
#  'USDT_CHZ',
#  'USDT_SLP',
#  'USDT_OGN',
#  'USDT_PLA',
#  'USDT_TLM',
#  'USDT_SUPER',
#  'USDT_ILV',
#  'USDT_ERN',
#  'USDT_SPELL',
#  'USDT_ICE',
#  'USDT_CHESS',
#  'USDT_EFI',
#  'USDT_RACA',
#  'USDT_AVAX',
#  'USDT_GMEE',
#  'USDT_REVV',
#  'USDT_MIM',
#  'USDT_CVX',
#  'USDT_O3',
#  'USDC_SHIB',
#  'USDC_AVAX',
#  'BTC_AVAX',
#  'USDT_SQUID',
#  'USDT_ENS',
#  'USDT_IMX',
#  'USDT_TIME',
#  'USDT_DOE',
#  'USDT_GM',
#  'USDT_GN',
#  'USDT_SAITAMA',
#  'USDT_MOCHI',
#  'USDT_BOBA',
#  'USDT_POLYDOGE',
#  'USDT_MC',
#  'USDT_ANY',
#  'USDT_FREN',
#  'USDT_HEX',
#  'USDT_FXS',
#  'USDT_DYP',
#  'USDT_TRIBE',
#  'USDT_KEEP',
#  'USDT_SOL',
#  'BTC_SOL',
#  'USDC_SOL',
#  'USDT_DORA',
#  'USDT_ORCA',
#  'USDT_PEOPLE',
#  'USDT_CRO',
#  'USDT_RARE',
#  'USDT_XDEFI',
#  'USDT_MPL',
#  'USDT_UDT',
#  'USDT_PRINTS',
#  'USDT_ANGLE',
#  'USDT_PSP',
#  'USDT_NEXO',
#  'USDT_FTM',
#  'USDT_BNX',
#  'USDT_SSG',
#  'USDT_GODZ',
#  'USDT_QI',
#  'USDT_JOE',
#  'USDT_ADA',
#  'USDT_REQ',
#  'USDT_SAMO',
#  'USDT_ATLAS',
#  'USDT_POLIS',
#  'USDT_FIDA',
#  'USDT_STEP',
#  'USDT_BICO',
#  'USDT_SFP',
#  'USDT_GF',
#  'USDT_BLZ',
#  'USDT_GODS',
#  'USDT_RBN',
#  'USDT_JBX',
#  'USDT_VADER',
#  'USDT_LIT',
#  'USDT_PYR',
#  'USDT_NCR',
#  'USDT_SOS',
#  'USDT_HIGH',
#  'USDT_FREE',
#  'USDT_VOXEL',
#  'BTC_ADA',
#  'USDC_ADA',
#  'USDT_CTC',
#  'USDT_METIS',
#  'USDT_OOKI',
#  'USDT_BTRFLY',
#  'USDT_LOOKS',
#  'USDC_FTM',
#  'BTC_FTM',
#  'USDT_SHPING',
#  'USDT_LOKA',
#  'USDT_VRA',
#  'USDT_SUKU',
#  'USDT_NCT',
#  'USDT_MQST',
#  'USDT_STRK',
#  'USDT_HUNT',
#  'USDT_UNFI',
#  'USDT_RND',
#  'USDT_TITAN',
#  'USDT_UMEE',
#  'USDT_X2Y2',
#  'USDT_MAGIC',
#  'USDT_ALPINE',
#  'USDT_LQDR',
#  'USDT_SPIRIT',
#  'USDT_JPEG',
#  'USDT_WLUNA',
#  'USDT_STRONG',
#  'USDT_AERGO',
#  'USDT_APE',
#  'USDT_NVIR']
